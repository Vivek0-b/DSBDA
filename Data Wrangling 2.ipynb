# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import pandas as pd
import numpy as np

# %%
data =pd.read_csv(r"C:\Users\abhin\OneDrive\Documents\Work\A2.csv")

# %%
df=pd.DataFrame(data)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Roll No       0
# Name          0
# Subject 1     0
# Subject 2     0
# Subject 3     1
# Subject 4     1
# Attendance    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll No     1001 non-null   int64
#  1   Name        1001 non-null   object
#  2   Subject 1   1001 non-null   int64
#  3   Subject 2   1001 non-null   int64
#  4   Subject 3   1000 non-null   float64
#  5   Subject 4   1000 non-null   float64
#  6   Attendance  1001 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 54.9+ KB

# %%
df.describe()
# Out:
#            Roll No    Subject 1    Subject 2    Subject 3    Subject 4  \
# count  1001.000000  1001.000000  1001.000000  1000.000000  1000.000000
# mean    500.000999    79.233766    80.064935    79.890000    80.545000
# std     289.106384    12.085913    11.904318    11.539457    11.793688
# min       1.000000    60.000000    60.000000    50.000000    40.000000
# 25%     250.000000    69.000000    70.000000    70.000000    71.000000
# 50%     500.000000    79.000000    80.000000    80.000000    81.000000
# 75%     750.000000    90.000000    91.000000    90.000000    91.000000
# max    1000.000000   100.000000   100.000000   100.000000   100.000000
#
#         Attendance
# count  1001.000000
# mean     85.416583
# std      10.277319
# min     -94.000000
# 25%      79.000000
# 50%      86.000000
# 75%      93.000000
# max     100.000000

# %%
df1=df.copy()
df1.fillna(0,inplace=True)
df1
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        0.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        0.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df2=df.copy()
df2=df2.ffill()
df2
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       71.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df3=df.copy()
df3=df3.bfill()
df3
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       99.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       84.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df4=df.copy()
df4["Subject 4"].fillna(85,inplace=True)
df4
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       85.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df5=df.copy()
df5["Subject 3"].fillna(df5["Subject 3"].mean(),inplace=True)
df5["Subject 4"].fillna(df5["Subject 4"].mean(),inplace=True)
df5
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df6=df.copy()
nc=['Subject 1','Subject 2','Subject 3','Subject 4','Attendance']
for c in nc:
    df6[c].fillna(df6[c].mean(),inplace=True)
df6
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df7=df.copy()
for c in nc:
    df7[c].fillna(df7[c].median(),inplace=True)
df7
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       81.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       80.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df7=df.copy()
for c in nc:
    df7[c].fillna(df7[c].mode(),inplace=True)
df7
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       95.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df7=df.copy()
df7.replace(to_replace=np.nan,value=85)
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       85.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       85.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df7=df.copy()
df7.interpolate(method='linear',limit_direction='forward')
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       95.5
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       77.5       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df7=df.copy()
df7.dropna()
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# 6             83
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [999 rows x 7 columns]

# %%
df7=df.copy()
df7.dropna(how='all',inplace=True)
df7
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df7=df.copy()
df7.dropna(axis=1)
# Out:
#       Roll No          Name  Subject 1  Subject 2  Attendance
# 0           1     Student_1        100         62          96
# 1           2     Student_2         72         97          78
# 2           3     Student_3        100         88         -94
# 3           4     Student_4         72         99          86
# 4           5     Student_5         97         70          86
# ...       ...           ...        ...        ...         ...
# 996       997   Student_997         88         68          98
# 997       998   Student_998         61         96          83
# 998       999   Student_999         72         76          90
# 999      1000  Student_1000         68         87          79
# 1000        1     Student_1        100         62          96
#
# [1001 rows x 5 columns]

# %%
df7=df.copy()
df7.dropna(axis=0,how='any')
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# 6             83
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [999 rows x 7 columns]

# %%
df7=df.copy()
print("Inconsistencies:\n",df7[df7[['Subject 1','Subject 2','Subject 3','Subject 4','Attendance']]<0])
# Out:
# Inconsistencies:
#        Roll No Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 2         NaN  NaN        NaN        NaN        NaN        NaN       -94.0
# 3         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 4         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# ...       ...  ...        ...        ...        ...        ...         ...
# 996       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 997       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 998       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 999       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1000      NaN  NaN        NaN        NaN        NaN        NaN         NaN
#
# [1001 rows x 7 columns]

# %%
df7[['Subject 3','Subject 4','Attendance']]=df7[['Subject 3','Subject 4','Attendance']].clip(lower=0)
df7
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2              0
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df7=df.copy()
df7.drop_duplicates(inplace=True)
df7
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0          1     Student_1        100         62       73.0       92.0
# 1          2     Student_2         72         97       82.0        NaN
# 2          3     Student_3        100         88       71.0       99.0
# 3          4     Student_4         72         99        NaN       84.0
# 4          5     Student_5         97         70       84.0       70.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996         74         89       85.0       71.0
# 996      997   Student_997         88         68       84.0       66.0
# 997      998   Student_998         61         96       62.0       84.0
# 998      999   Student_999         72         76       90.0       72.0
# 999     1000  Student_1000         68         87      100.0       76.0
#
#      Attendance
# 0            96
# 1            78
# 2           -94
# 3            86
# 4            86
# ..          ...
# 995          87
# 996          98
# 997          83
# 998          90
# 999          79
#
# [1000 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df7=df.copy()
nc=['Subject 1','Subject 2','Subject 3','Subject 4','Attendance']
for c in nc:
    sns.boxplot(x=df7[c])
    plt.title(f'BoxPlot of {c}')
    plt.show()

# %%
df7=df.copy()
for c in nc:
    Q1=df7[c].quantile(0.25)
    Q3=df7[c].quantile(0.75)
    IQR=Q3-Q1
    
    
    lower_bound=Q1-1.5*IQR
    upper_bound=Q3+1.5*IQR
    
    df7[c]=np.where((df7[c]<lower_bound)|(df7[c]>upper_bound),df7[c].median(),df7[c])
df7
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1      100.0       62.0       73.0       92.0
# 1           2     Student_2       72.0       97.0       82.0        NaN
# 2           3     Student_3      100.0       88.0       71.0       99.0
# 3           4     Student_4       72.0       99.0        NaN       84.0
# 4           5     Student_5       97.0       70.0       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997       88.0       68.0       84.0       66.0
# 997       998   Student_998       61.0       96.0       62.0       84.0
# 998       999   Student_999       72.0       76.0       90.0       72.0
# 999      1000  Student_1000       68.0       87.0      100.0       76.0
# 1000        1     Student_1      100.0       62.0       73.0       92.0
#
#       Attendance
# 0           96.0
# 1           78.0
# 2           86.0
# 3           86.0
# 4           86.0
# ...          ...
# 996         98.0
# 997         83.0
# 998         90.0
# 999         79.0
# 1000        96.0
#
# [1001 rows x 7 columns]

# %%
df7=df.copy()
from scipy import stats
import numpy as np

z=np.abs(stats.zscore(df7['Subject 1']))
z
# Out:
# array([1.7190769 , 0.59882791, 1.7190769 , ..., 0.59882791, 0.92995717,
#        1.7190769 ], shape=(1001,))

# %%
threshold=1
print(np.where(z>1))
# Out:
# (array([   0,    2,    4,    5,    6,    7,    8,   10,   13,   15,   17,
#          22,   24,   25,   27,   28,   29,   33,   37,   38,   48,   49,
#          50,   53,   56,   57,   59,   60,   62,   68,   69,   71,   74,
#          75,   77,   78,   80,   87,   90,   91,   97,   98,   99,  102,
#         104,  108,  113,  114,  117,  124,  126,  128,  133,  136,  139,
#         140,  141,  142,  143,  145,  150,  151,  153,  158,  159,  160,
#         161,  162,  165,  169,  173,  174,  176,  177,  179,  182,  185,
#         187,  188,  194,  198,  199,  200,  213,  216,  217,  218,  220,
#         222,  226,  227,  228,  230,  231,  232,  233,  235,  237,  240,
#         242,  246,  247,  248,  251,  256,  257,  258,  264,  265,  266,
#         267,  268,  269,  270,  271,  272,  275,  278,  280,  282,  286,
#         287,  292,  294,  295,  297,  298,  308,  309,  310,  313,  315,
#         316,  317,  319,  320,  321,  322,  323,  325,  327,  328,  329,
#         332,  335,  336,  338,  339,  343,  345,  346,  349,  350,  351,
#         352,  356,  360,  362,  364,  365,  366,  371,  373,  374,  375,
#         376,  379,  381,  382,  383,  384,  390,  391,  393,  395,  399,
#         400,  403,  404,  418,  419,  422,  423,  426,  427,  428,  430,
#         435,  436,  439,  440,  442,  445,  447,  449,  454,  455,  457,
#         458,  461,  462,  464,  465,  466,  469,  470,  474,  476,  478,
#         481,  483,  485,  488,  489,  492,  495,  497,  499,  503,  504,
#         505,  506,  507,  509,  510,  511,  513,  515,  518,  519,  520,
#         522,  527,  529,  532,  534,  537,  540,  541,  542,  546,  558,
#         560,  561,  563,  564,  568,  569,  572,  578,  580,  581,  582,
#         584,  588,  591,  592,  595,  597,  598,  601,  602,  603,  605,
#         614,  615,  616,  617,  621,  633,  637,  638,  639,  642,  645,
#         647,  648,  649,  651,  652,  653,  658,  660,  661,  663,  673,
#         675,  677,  679,  681,  685,  686,  687,  688,  693,  695,  698,
#         701,  702,  703,  704,  706,  707,  708,  712,  713,  714,  715,
#         717,  718,  725,  726,  730,  731,  732,  735,  736,  737,  738,
#         739,  741,  743,  748,  749,  750,  751,  752,  757,  758,  761,
#         763,  766,  767,  770,  772,  774,  775,  776,  779,  781,  782,
#         786,  789,  794,  799,  800,  801,  804,  805,  806,  812,  813,
#         814,  819,  820,  821,  822,  823,  824,  825,  826,  829,  831,
#         833,  834,  835,  836,  846,  850,  852,  854,  858,  859,  861,
#         862,  866,  867,  868,  869,  871,  873,  876,  877,  878,  879,
#         881,  885,  886,  887,  889,  890,  891,  892,  893,  894,  897,
#         901,  904,  906,  909,  911,  912,  914,  919,  920,  923,  926,
#         927,  932,  935,  936,  938,  944,  947,  948,  949,  950,  951,
#         952,  953,  954,  955,  958,  961,  962,  971,  972,  973,  977,
#         979,  980,  983,  984,  986,  987,  988,  989,  991,  992,  997,
#        1000]),)

# %%
df7['log_Attendance']=np.log1p(df7['Attendance'])
df7
# Out:
# C:\Users\abhin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance  log_Attendance
# 0             96        4.574711
# 1             78        4.369448
# 2            -94             NaN
# 3             86        4.465908
# 4             86        4.465908
# ...          ...             ...
# 996           98        4.595120
# 997           83        4.430817
# 998           90        4.510860
# 999           79        4.382027
# 1000          96        4.574711
#
# [1001 rows x 8 columns]

# %%
df7 = df.copy()
for c in nc:
    print('column:', c, 'Skew:', df7[c].skew(skipna=True))
# Out:
# column: Subject 1 Skew: 0.0914099786360925
# column: Subject 2 Skew: -0.010695777003801397
# column: Subject 3 Skew: 0.006016983906506895
# column: Subject 4 Skew: -0.0682976550582128
# column: Attendance Skew: -5.348145768243219

# %%
from scipy.stats import norm
for c in nc:
    data = df7[c]
    
    mean = data.mean()
    sd = data.std()
    
    x_axis = np.linspace(data.min(), data.max(), 100)
    y_axis = norm.pdf(x_axis, mean, sd)
    
    plt.plot(x_axis, y_axis, label=f'{c} Normal Distribution')
    
plt.legend()
plt.show()

# %%
for c in nc:
    sns.histplot(df[c], kde=True)
    plt.title(f'Distribution of {c}')
    plt.show()
